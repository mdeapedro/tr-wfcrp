# %%
import sys
sys.path.append('../src')
import networkx as nx

from instance import Instance
from solution import Solution
from best_sweep import best_sweep
from plot import plot, plot_instance
from transgenetic import transgenetic

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
instance = Instance(
    instance_dir='../instances',
    instance='n120_s04_t01_w01'
)

# %%
G = nx.Graph()
for i in range(instance.n+1): G.add_node(i, pos=instance.nodes[i])
pos = nx.get_node_attributes(G, 'pos')

# %%
plot_instance(instance)

# %%
best_sweep_solution = Solution(instance, best_sweep(instance))

# %%
plot(best_sweep_solution)
print(best_sweep_solution.cost())
# Out:
# 88083651

# %%
transgenetic_solution = transgenetic(instance, 20, instance.n//10, 0.5, 0.5, 100)

# %%
plot(transgenetic_solution)
print(transgenetic_solution.cost())
# Out:
# 87770638
